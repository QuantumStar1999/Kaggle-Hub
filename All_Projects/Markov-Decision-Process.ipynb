# %%
# !pip install gym gymnasium

# %%
# !wget -q https://raw.githubusercontent.com/escape-velocity-labs/beginner_master_rl/main/envs.py

# %%
# !cat envs.py | head -10
# Out:
# """
# Maze environment used in the first three modules of the course:
# "Beginner to Master: Reinforcement Learning".
# """
#
#
# from typing import Tuple, Dict, Optional, Iterable
#
# import numpy as np

# %%
import gymnasium as gym
import numpy as np
from IPython import display
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import envs as e
e.Maze()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-065ea48045f2> in <cell line: 2>()
#       1 import envs as e
# ----> 2 e.Maze()
#
# AttributeError: module 'envs' has no attribute 'Maze'

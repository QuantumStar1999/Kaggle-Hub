# %%
import numpy as np
x = [(-3,-3),(-1,-1),(1,1),(3,3)]

# %%
x=np.array(x)

# %%
np.matmul(x.T,x)
# Out:
# array([[20, 20],
#        [20, 20]])

# %%
x.shape
# Out:
# (4, 2)

# %%
y = np.matmul(x.T,x)
np.cov(y)
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
import numpy as np
x = [(-3,-3),(-1,-1),(1,1),(3,3)]
x=np.array(x)
y = np.matmul(x.T,x)
evalue, evec = np.linalg.eig(y)
evalue
# Out:
# array([4.00000000e+01, 3.55271368e-15])

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize

text = 'Hey dude, I am learning NLP. How super cool is that!'

print (text.split())

print (word_tokenize (text))
# Out:
# ['Hey', 'dude,', 'I', 'am', 'learning', 'NLP.', 'How', 'super', 'cool', 'is', 'that!']
# ['Hey', 'dude', ',', 'I', 'am', 'learning', 'NLP', '.', 'How', 'super', 'cool', 'is', 'that', '!']

# %%
import re
text = "How' re you goin'? I hope you're doing great!"
text = re.sub(u"[a-zA-Z0-9]", "", text)
print(text.split())
# Out:
# ["'", "'?", "'", '!']
